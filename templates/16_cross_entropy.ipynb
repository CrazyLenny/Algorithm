# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/16_cross_entropy.ipynb)
#
# # 🟢 Easy: Cross-Entropy Loss
#
# Implement **cross-entropy loss** from scratch.
#
# $$\text{CE}(x, y) = -\log\frac{e^{x_y}}{\sum_j e^{x_j}}$$
#
# ### Signature
# ```python
# def cross_entropy_loss(logits: Tensor, targets: Tensor) -> Tensor:
#     # logits: (B, C) float, targets: (B,) long indices
#     # Returns: scalar loss (mean over batch)
# ```
#
# ### Rules
# - Do NOT use `F.cross_entropy` or `nn.CrossEntropyLoss`
# - Must be numerically stable (use logsumexp trick)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.0 MB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def cross_entropy_loss(logits, targets):
  # log(sum(exp(x_i))) - logit
  # log(sum(exp_x_i))): trick is to substract the maximum first
  max_logit = torch.max(logits, dim=-1, keepdim=True).values
  stable_logit = logits - max_logit

  log_sum_exp = torch.log(torch.sum(torch.exp(stable_logit), dim=-1, keepdim=True))

  ce = - stable_logit + torch.log(torch.sum(torch.exp(stable_logit), dim=-1, keepdim=True))
  return ce[targets]

# %%
# 🧪 Debug
logits = torch.randn(4, 10)
targets = torch.randint(0, 10, (4,))
print('Loss:', cross_entropy_loss(logits, targets))
print('Ref: ', torch.nn.functional.cross_entropy(logits, targets))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2638/795304180.py in <cell line: 0>()
#       2 logits = torch.randn(4, 10)
#       3 targets = torch.randint(0, 10, (4,))
# ----> 4 print('Loss:', cross_entropy_loss(logits, targets))
#       5 print('Ref: ', torch.nn.functional.cross_entropy(logits, targets))
#
# /tmp/ipykernel_2638/2969550254.py in cross_entropy_loss(logits, targets)
#       7   stable_logit = logits - max_logit
#       8   ce = - stable_logit + torch.log(torch.sum(torch.exp(stable_logit), dim=-1, keepdim=True))
# ----> 9   return ce[targets]
#
# IndexError: index 9 is out of bounds for dimension 0 with size 4

# %%
# ✅ SUBMIT
from torch_judge import check
check('cross_entropy')
